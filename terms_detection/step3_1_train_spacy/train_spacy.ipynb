# %%
# !prodigy db-in ner_combine_filtered ner_C07K_combine_filtered.jsonl
# Out:
# ✔ Created dataset 'ner_combine_filtered' in database SQLite
# ✔ Imported 777 annotations to 'ner_combine_filtered' (session
# 2023-04-23_15-07-30) in database SQLite
# Found and keeping existing "answer" in 777 examples

# %%
# !prodigy train NER_model_filtered --ner ner_combine_filtered --training.max_steps=2000 --training.optimizer.learn_rate=0.001 --base-model=en_core_web_sm
# Out:
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ========================= Generating Prodigy config =========================
# ℹ Auto-generating config with spaCy
# ℹ Using config from base model
# ✔ Generated training config
#
# =========================== Initializing pipeline ===========================
# [2023-04-23 15:08:13,274] [INFO] Set up nlp object from config
# Components: ner
# Merging training and evaluation data for 1 components
#   - [ner] Training: 232 | Evaluation: 57 (20% split)
# Training: 192 | Evaluation: 44
# Labels: ner (3)
# [2023-04-23 15:08:13,423] [INFO] Pipeline: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# [2023-04-23 15:08:13,423] [INFO] Resuming training for: ['ner', 'tok2vec']
# [2023-04-23 15:08:13,428] [INFO] Created vocabulary
# [2023-04-23 15:08:13,429] [INFO] Finished initializing nlp object
# [2023-04-23 15:08:13,429] [INFO] Initialized pipeline components: []
# ✔ Initialized pipeline
#
# ...

# %%
import spacy
c07k=open('../../C07K.txt').read().strip()
patent_lines = c07k.split('\n')

nlp_ner = spacy.load("./NER_model_filtered/model-best")

colors = {"TECH": "#7DF6D9", "MEDICALCONDITION":"#FFFFFF"}
options = {"colors": colors} 

for line in patent_lines[10000:10010]:
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A method of preparing an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     antibody suitable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Term</span>
# </mark>
#  for use in a canine is provided. Also provided are caninised antibodies which specifically bind to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canine neuronal growth factor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Term</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...
